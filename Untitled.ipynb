# %%
#!pip install pandas
import pandas as pd
dict = {str(int(0)-126)+"~"+str(int(0)): "0"}
series = pd.Series(dict, index=None)
print(series)
# Out:
# -126~0    0
# dtype: object

# %%
from lib.ddeclient import DDEClient


def rss(code, item):
	""" 楽天RSSから情報を取得
	Parameters
	----------
	code : str
		株価や先物のコード　例：東京電力の場合'9501.T'
	item :
	Returns
	-------
	str
	Examples
	----------
	>>>rss('9501.T' , '始値')
	'668.00'
	>>>rss('9501.T' , '現在値')
	'669.00'
	>>>rss('9501.T' , '銘柄名称')
	'東京電力ＨＤ'
	>>>rss('9501.T' , '現在値詳細時刻')
	'15:00:00'
	"""

	dde = DDEClient("rss", str(code))
	try:
		res = dde.request(item).decode("sjis")#strip()
	except:
		print('fail: code@', code)
		res = 0
	finally:
		dde.__del__()
	return res
rss('9501.T' , '現在値')
def rss_dict(code, *args):
	"""
	楽天RSSから辞書形式で情報を取り出す(複数の詳細情報問い合わせ可）
	Parameters
	----------
	code : str
	args : *str
	Returns
	-------
	dict
	Examples
	----------
	>>>rss_dict('9502.T', '始値','銘柄名称','現在値')
	{'始値': '1739.50', '現在値': '1661.50', '銘柄名称': '中部電力'}
	"""

	dde = DDEClient("rss", str(code))
	res = {}
	try:
		for item in args:
			res[item] = dde.request(item).decode('sjis').strip()
	except:
		print('fail: code@', code)
		res = {}
	finally:
		dde.__del__()
	return res


def fetch_open(code):
	""" 始値を返す（SQ計算用に関数切り出し,入力int）
	Parameters
	----------
	code : int
	Examples
	---------
	>>> fetch_open(9551)
	50050
	"""

	return float(rss(str(code) + '.T', '始値'))

# %%
rss("1306.T", "現在値")
# Out:
# '   2067.50'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24340/3632748084.py in <module>
#       8     #print(temp)
#       9     for i in range(1000):
# ---> 10         print(a, b, format= "%H時%M分%S秒")
#      11
#
# TypeError: 'format' is an invalid keyword argument for print()

# %%
import pandas as pd

with pd.HDFStore("630.hdf5") as store:
    temp =store.get("time")
    
    a= temp["time_start"].to_list()
    l =len(a)
    print(l)
    
    b =temp["time_end"].to_list()
    #b = reversed(b)
    #temp["1"] = pd.to_datetime(a,  format="%H時%M分%S秒")
    #a =pd.to_datetime(temp)
    pre_temp = 0
    dict = {}
    
    for i in range(80000):
        txt  = (str(a[i].hour)+":"+str(a[i].minute).zfill(2)+":"+str(a[i].second).zfill(2), str(b[i].hour)+":"+str(b[i].minute).zfill(2)+":"+str(b[i].second).zfill(2),float(b[i].timestamp())-float(a[i].timestamp()))
        if i==0:
            print(txt)
        temp = float(b[i].timestamp())-float(a[i].timestamp())
        if temp > 26:
            print(txt)
        elif temp > 4:
            print(txt)
        elif temp > 2.5:
            print(txt)
    
        dict[i] = temp
    temp = list(dict.values())      
    temp = sorted(temp, reverse=True)
    count=0
    for i in temp:
        if i > 0.1:
            print(i)
            count+= 1
        else:
            break
    #print(temp[0], temp[1], temp[2], temp[3], temp[4], temp[5])
    print(count)
    """
    b = pd.to_datetime(b,  format= "%H時%M分%S秒")
    c = a.to_list()
    d = b.to_list()
    #print(temp)
    for i in range(1000):
        print(a, b)
    """
# Out:
# 81458
# ('13:06:31', '13:06:54', 23.23451805114746)
# ('13:06:31', '13:06:54', 23.23451805114746)
# 23.23451805114746
# 0.2591898441314697
# 0.1872708797454834
# 0.18356800079345703
# 0.17343997955322266
# 0.15653395652770996
# 0.15577197074890137
# 0.14933085441589355
# 0.1406078338623047
# 0.14054584503173828
# 0.1404709815979004
# 0.1255500316619873
# 0.12548112869262695
# 0.12539887428283691
# 0.12510299682617188
# 0.1250300407409668
# 0.12500500679016113
# 0.12494301795959473
# 0.12490987777709961
# 0.12482690811157227
# 0.12457990646362305
# 0.12441778182983398
# 0.11509418487548828
# 0.11007094383239746
# 0.10968995094299316
# 0.10962891578674316
# 0.10959005355834961
# 0.10946512222290039
# 0.10940313339233398
# 0.10938596725463867
# 0.1092379093170166
# 0.10919594764709473
# 0.10914993286132812
# 0.10908794403076172
# 0.10905694961547852
# 0.10897517204284668

# %% [markdown]
# #126
# 26.062400102615356
# 4.265471935272217 ('13:08:43', '13:08:47', 4.265471935272217)
# 0.5940220355987549
# 0.3439931869506836
# 0.18709802627563477
# 0.17082715034484863
# 0.11689496040344238
# 0.10938096046447754
# 0.10935711860656738

# %%
('13:06:31', '13:06:54', 23.23451805114746)
23.23451805114746
0.2591898441314697
0.1872708797454834
0.18356800079345703
0.17343997955322266
0.15653395652770996
0.15577197074890137
0.14933085441589355
0.1406078338623047
0.14054584503173828
0.1404709815979004
0.1255500316619873
0.12548112869262695
0.12539887428283691
0.12510299682617188
0.1250300407409668
0.12500500679016113
0.12494301795959473
0.12490987777709961
0.12482690811157227
0.12457990646362305
0.12441778182983398
0.11509418487548828
0.11007094383239746
0.10968995094299316
0.10962891578674316
0.10959005355834961
0.10946512222290039
0.10940313339233398
0.10938596725463867
0.1092379093170166
0.10919594764709473
0.10914993286132812
0.10908794403076172
0.10905694961547852
0.10897517204284668

# %%
import pandas as pd
with pd.HDFStore("630-DESKTOP-Q1MCOAI.hdf5") as store:
    temp =store.get("time")
    
    a= temp["time_start"].to_list()
    b =temp["time_end"]
    d =pd.to_datetime(b,format= "%H時%M分%S秒")
    
   
    #d = pd.to_datetime(d,  )
    print(d)
    """
    c = a.to_list()
    d = b.to_list()
    #print(temp)
    for i in range(1000):
        print(a, b)
    """
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24340/2253414963.py in <module>
#       1 import pandas as pd
#       2 with pd.HDFStore("630-DESKTOP-Q1MCOAI.hdf5") as store:
# ----> 3     temp =store.get("time")
#       4
#       5     a= temp["time_start"].to_list()
#
# ~\anaconda3\lib\site-packages\pandas\io\pytables.py in get(self, key)
#     797             group = self.get_node(key)
#     798             if group is None:
# --> 799                 raise KeyError(f"No object named {key} in the file")
#     800             return self._read_group(group)
#     801
#
# KeyError: 'No object named time in the file'

# %%
import numpy as np
import pandas as pd
import time
class LastNPerfTime:
    def __init__(self, n):
        """
        過去n回の実行時間の合計を尺取り法で記録する
        """
        self.n = n
        self.count = 0
        self.sum_time = 0
        self.times = np.zeros(n) #ゼロお要素とする配列を創る
        
        
    def start(self):
        """
        実行時間の計測を開始する
        """
        self.start_time = time.perf_counter() # timeより正確
        
    def end(self):
        """
        実行時間の計測を終了する
        """
        dtime = time.perf_counter() - self.start_time
        idx = self.count % self.n # self.nが2^xならここをビット論理積にできる
        time_n_before = self.times[idx]
        self.times[idx] = dtime
        self.count += 1
        self.sum_time += (dtime - time_n_before)
        
    def get_sum_time(self):
        """
        過去n回の実行時間を合計した値を返す
        """
        return self.sum_time

# %%
a = LastNPerfTime(10)
a.__init__(5)
